# %% [markdown]
# # <b>Unsupervised Learning Week: Clustering</b>
#
# **Goals**
#
# - Clustering. What is it? Why is it used? What makes it qualify as unsupervised learning.
# - KMeans: The most popular clustering algorithm. How to use KMeans with Sklearn.
# - How to evaluate KMeans using Sklearn.
# - In class workshop: pick a dataset and do some clustering!!

# %% [markdown]
# ## What is clustering? What is unsupervised learning?

# %% [markdown]
# ## Clustering
#
# Clustering comes natural to humans. We categorize each others, things, and other phenomenon all the time i.e. Millennials vs Generation X vs Boomers and Tudor vs Hacienda vs Contemporary houses. Categorizing helps us better understand things; if you tell me a certain person or thing belongs to a certain label, then I immediately gain a better understanding of their or its purpose.
# <br><br>
# What do you think are real world applications of clustering? Why would this be valuable to a business?
# <br><br>
# "Clustering is a technique for finding similarity groups in a data, called clusters. It attempts to group individuals in a population together by similarity, but not driven by a specific purpose." http://bigdata-madesimple.com/possibly-the-simplest-way-to-explain-k-means-algorithm/
# <br><br>
# <b>CLUSTERING IS UNSUPERVISED LEARNING BECAUSE THERE ARE NO LABELS LIKE IN SUPERVISED LEARNING. THE POINT OF CLUSTERING IS TO GENERATE NEW LABELS FROM UNLABELLED DATA<b>

# %%
#Imports
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs, make_moons, make_circles, make_classification
plt.style.use("fivethirtyeight")

# %%
#Make fake data to visualize
data = make_blobs(n_samples=250, centers = 4, cluster_std=.75, random_state=4)[0]

# %%
plt.figure(figsize=(10,6))
plt.scatter(data[:,0], data[:,1], s=68);

# %% [markdown]
# ### How many clusters do you see?

# %% [markdown]
# Clustering is usually never this easy. Let's look at some more difficult data.

# %%
#Make fake data
data = make_classification(n_samples=400, n_features=2, n_informative=2,
                           n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=2, random_state=1)[0]

# %%
plt.figure(figsize=(10,6))
plt.scatter(data[:,0], data[:,1], s=68, alpha=.6);

# %% [markdown]
# ## KMeans Algorithm
#
# - The most popular clustering algorithm
# - K in Kmeans stands for the number of clusters and centriods predetermined by you the data scientist.
# - Centriods are the center point of each cluster. The average of all of the points in the cluster, hence the means in kmeans.
# - A point is assigned to the cluster of the centriod it is closest to.
# - Algorithms works by randomly assigning centriods within the data and shifts the centriods until they reach convergence.
# - Basically means the algorithm keeps going until it finds the smallest value produced by this function:
# $$∑(x¯c−xi)^2$$
# <br><br>
# ### KMeans in action
#
# ![a](http://stanford.edu/~cpiech/cs221/img/kmeansViz.png)

# %% [markdown]
# Interactive version:
#
# http://stanford.edu/class/ee103/visualizations/kmeans/kmeans.html

# %% [markdown]
# **Things to keep in mind**
#
# - Needs features on the same or similar scales to be effective.
#
# - Vulnerable to noise from too many features and multicollinearity.
#
# - Assumes a linear boundary between clusters, which is not always the case as we're about to see.

# %% [markdown]
# ### Clustering Time

# %% [markdown]
# We're going to use KMeans to cluster different forms of data to demonstrate how abilities and limitations of KMeans.

# %% [markdown]
# Let's bring back the blobs and use KMeans on it.

# %%
#Make fake data to visualize
data = make_blobs(n_samples=250, centers = 4, cluster_std=.75, random_state=4)[0]

plt.figure(figsize=(10,6))
plt.scatter(data[:,0], data[:,1], s=68);

# %%
#Intialize the KMeans algorithm with 3 clusters
km3 = KMeans(n_clusters=3)

#Fit model on data
km3.fit(data)

#Get the labels
labels = km3.labels_

labels[:10]
# Out:
# array([2, 1, 0, 0, 2, 0, 0, 0, 0, 1], dtype=int32)

# %%
#Can derive labels this way as well, using .predict
km3.predict(data)[:10]
# Out:
# array([2, 1, 0, 0, 2, 0, 0, 0, 0, 1], dtype=int32)

# %%
#The counts of labels
pd.value_counts(labels)
# Out:
# 0    126
# 2     62
# 1     62
# dtype: int64

# %%
#Visualize the data with the color-encoded labels

plt.figure(figsize=(10, 6))
plt.scatter(data[:,0], data[:,1], s = 70, c = labels)

# %% [markdown]
# Is this what you expected?

# %% [markdown]
# Centriods: The center point of each cluster. Equivalent to the average of the attributes for each label
#
# Let's replot the above chart but with the centriods.

# %%
#Centriod values

centriods = km3.cluster_centers_
centriods
# Out:
# array([[ 9.47719408,  2.61510626],
#        [ 4.07638897, -5.47320984],
#        [ 9.61095813, -9.97869912]])

# %%
#Visualize the data with the color-encoded labels along with the centriods

plt.figure(figsize=(8,7))
plt.scatter(data[:, 0], data[:, 1], s = 70, c=labels, alpha=.6)
plt.scatter(centriods[:, 0], centriods[:, 1], s = 800, marker= "+", c = "black");

# %% [markdown]
# Let's try it again with four clusters

# %%
#Intialize the KMeans algorithm with 4 clusters
km4 = KMeans(n_clusters=4)


#Fit model on data
km4.fit(data)

#Get the labels
labels = km4.labels_

# %%
#The counts of labels
pd.value_counts(labels)
# Out:
# 3    63
# 1    63
# 2    62
# 0    62
# dtype: int64

# %%
#Visualization
centriods = km4.cluster_centers_


plt.figure(figsize=(10, 6))
plt.scatter(data[:,0], data[:,1], s = 70, c = labels, alpha=.6)
plt.scatter(centriods[:, 0], centriods[:, 1], s = 800, marker= "+", c = "black");

# %% [markdown]
# Does this change your answer to the "How many clusters do you see?" question.

# %% [markdown]
# Cluster the random data from earlier

# %%
#Make fake data
data = make_classification(n_samples=400, n_features=2,n_informative=2,
                           n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=2, random_state=1)[0]

#Visualize
plt.figure(figsize=(10,6))
plt.scatter(data[:,0], data[:,1], s=68, alpha=.6);

# %% [markdown]
# What cluster value should we set?

# %%
#Intialize the KMeans algorithm with 4 clusters
km = KMeans(n_clusters=4)


#Fit model on data
km.fit(data)

#Get the labels
labels = km.labels_

#Assign centriods

cents = km.cluster_centers_

#Values counts of labels
pd.value_counts(labels)
# Out:
# 0    120
# 1    113
# 2     92
# 3     75
# dtype: int64

# %%
#Visualize color-encoded data

plt.figure(figsize=(8,6))
plt.scatter(data[:, 0], data[:, 1], c = labels, s = 70, alpha=.6)
plt.scatter(cents[:, 0], cents[:, 1], c = "black", marker="+", s = 700)

# %% [markdown]
# Is this what you expected?

# %% [markdown]
# Let's try this on "moons" data.

# %%
#Make moon data

data = make_moons(n_samples=400, noise=.10)[0]

#Visualize
plt.figure(figsize=(10,6))
plt.scatter(data[:,0], data[:,1], s=68, alpha=.6);

# %% [markdown]
# Cluster with 2 clusters

# %%
#Intialize the KMeans algorithm with 2 clusters
km2 = KMeans(n_clusters=2)


#Fit model on data
km2.fit(data)

#Get the labels
labels = km2.labels_


#Centriods
cents = km2.cluster_centers_



#Visualize color-encoded data
plt.figure(figsize=(8, 7))
plt.scatter(data[:, 0], data[:, 1], c= labels, s = 70, alpha=.5)
plt.scatter(cents[:, 0], cents[:, 1], c = "black", marker= "+", s = 700)

# %% [markdown]
# How do you rate the results of this clustering algorithm?

# %% [markdown]
# Let's use KMeans on "circles"

# %%
#Make circles data

data = make_circles(n_samples=800, noise=.05, factor=0.5)[0]

#Visualize
plt.figure(figsize=(10,6))
plt.scatter(data[:,0], data[:,1], s=68, alpha=.6);

# %% [markdown]
# How do you think this data will interact with KMeans?

# %% [markdown]
# Let's find out.

# %%
#Intialize the KMeans algorithm with 2 clusters
km2 = KMeans(n_clusters=2)


#Fit model on data
km2.fit(data)

#Get the labels
labels = km2.labels_


#Centriods
cents = km2.cluster_centers_



#Visualize color-encoded data
plt.figure(figsize=(8, 7))
plt.scatter(data[:, 0], data[:, 1], c = labels, s = 70, alpha=.5)
plt.scatter(cents[:, 0], cents[:, 1], c = "black", marker="+", s = 700)

# %% [markdown]
# Does this match your expectation?

# %% [markdown]
# KMeans is great but not it's not perfect, there's other algorithm that are better clustering the the types of data KMean is not good at clustering.
#
# <br>
#
# Now let's use KMeans on real world data.

# %% [markdown]
# ## Clustering Country Data
#
# <br>
#
# - In this section we're going to use KMeans to cluster countries based on their socio-economic attributes such as unemployment, electricity, and infant mortality.
#
# - How to evaluate clusters using the elbow method and silhouette score
#
# - Scaling features improves results

# %%
path = "../../data/country_development_data.pkl"

#Load in data and assign it to df
df = pd.read_pickle(path)

#Look at first five rows
df.head()
# Out:
# IndicatorCode  Access to electricity (% of population)  \
# CountryName
# Afghanistan                                       43.0
# Albania                                          100.0
# Algeria                                          100.0
# Angola                                            37.0
# Argentina                                         99.8
#
# IndicatorCode  Renewable electricity output (% of total electricity output)  \
# CountryName
# Afghanistan                                             0.000000
# Albania                                               100.000000
# Algeria                                                 1.083680
# Angola                                                 70.906823
# Argentina                                              23.769069
#
# IndicatorCode  CO2 emissions (metric tons per capita)  \
# CountryName
# Afghanistan                                  0.425262
# Albania                                      1.607038
# Algeria                                      3.316038
# Angola                                       1.354008
# Argentina                                    4.562049
#
# IndicatorCode  Commercial bank branches (per 100,000 adults)  \
# CountryName
# Afghanistan                                         2.465221
# Albania                                            22.241690
# Algeria                                             5.064181
# Angola                                             12.863257
# Argentina                                          13.303817
#
# IndicatorCode  Depth of credit information index (0=low to 8=high)  \
# CountryName
# Afghanistan                                                  0.0
# Albania                                                      6.0
# Algeria                                                      0.0
# Angola                                                       0.0
# Argentina                                                    8.0
#
# IndicatorCode  Strength of legal rights index (0=weak to 12=strong)  \
# CountryName
# Afghanistan                                                  9.0
# Albania                                                      7.0
# Algeria                                                      2.0
# Angola                                                       1.0
# Argentina                                                    2.0
#
# IndicatorCode  Mobile cellular subscriptions (per 100 people)  \
# CountryName
# Afghanistan                                         74.882842
# Albania                                            105.469966
# Algeria                                             93.310750
# Angola                                              63.479208
# Argentina                                          158.735762
#
# IndicatorCode  Internet users (per 100 people)  GDP per capita (current US$)  \
# CountryName
# Afghanistan                               6.39                    633.569247
# Albania                                  60.10                   4564.390339
# Algeria                                  18.09                   5484.066806
# Angola                                   21.26                   5900.529570
# Argentina                                64.70                  12509.531118
#
# IndicatorCode  Proportion of seats held by women in national parliaments (%)  \
# CountryName
# Afghanistan                                            27.710843
# Albania                                                20.714286
# Algeria                                                31.601732
# Angola                                                 36.818182
# Argentina                                              36.186770
#
# IndicatorCode  Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# CountryName
# Afghanistan                                                 46.0
# Albania                                                      5.1
# Algeria                                                     14.5
# Angola                                                      66.4
# Argentina                                                   11.3
#
# IndicatorCode  Health expenditure per capita (current US$)  \
# CountryName
# Afghanistan                                      54.964148
# Albania                                         239.577092
# Algeria                                         313.520212
# Angola                                          267.224299
# Argentina                                      1074.066944
#
# IndicatorCode  Labor force, female (% of total labor force)  \
# CountryName
# Afghanistan                                       16.051439
# Albania                                           41.266475
# Algeria                                           17.376156
# Angola                                            46.204554
# Argentina                                         40.431360
#
# IndicatorCode  Unemployment, total (% of total labor force)  Net migration  \
# CountryName
# Afghanistan                                             9.1         473007
# Albania                                                16.1         -91750
# Algeria                                                 9.5        -143268
# Angola                                                  6.8         102322
# Argentina                                               8.2          30000
#
# IndicatorCode  Mortality rate, infant (per 1,000 live births)  \
# CountryName
# Afghanistan                                              66.3
# Albania                                                  12.5
# Algeria                                                  21.9
# Angola                                                   96.0
# Argentina                                                11.1
#
# IndicatorCode  Life expectancy at birth, total (years)  \
# CountryName
# Afghanistan                                  60.028268
# Albania                                      77.537244
# Algeria                                      74.568951
# Angola                                       51.866171
# Argentina                                    75.986098
#
# IndicatorCode  Survival to age 65, female (% of cohort)  \
# CountryName
# Afghanistan                                    60.48056
# Albania                                        90.56197
# Algeria                                        85.02157
# Angola                                         49.09112
# Argentina                                      87.23494
#
# IndicatorCode  Population, ages 0-14 (% of total)  \
# CountryName
# Afghanistan                             44.870996
# Albania                                 18.930427
# Algeria                                 28.205909
# Angola                                  47.850317
# Argentina                               25.346427
#
# IndicatorCode  Age dependency ratio, young (% of working-age population)  \
# CountryName
# Afghanistan                                            85.153384
# Albania                                                27.432462
# Algeria                                                42.742285
# Angola                                                 96.005760
# Argentina                                              39.700196
#
# IndicatorCode  Urban population (% of total)
# CountryName
# Afghanistan                           26.282
# Albania                               56.409
# Algeria                               70.129
# Angola                                43.274
# Argentina                             91.604

# %%
pd.set_option("max.columns", 100)
df.head()
# Out:
# IndicatorCode  Access to electricity (% of population)  \
# CountryName
# Afghanistan                                       43.0
# Albania                                          100.0
# Algeria                                          100.0
# Angola                                            37.0
# Argentina                                         99.8
#
# IndicatorCode  Renewable electricity output (% of total electricity output)  \
# CountryName
# Afghanistan                                             0.000000
# Albania                                               100.000000
# Algeria                                                 1.083680
# Angola                                                 70.906823
# Argentina                                              23.769069
#
# IndicatorCode  CO2 emissions (metric tons per capita)  \
# CountryName
# Afghanistan                                  0.425262
# Albania                                      1.607038
# Algeria                                      3.316038
# Angola                                       1.354008
# Argentina                                    4.562049
#
# IndicatorCode  Commercial bank branches (per 100,000 adults)  \
# CountryName
# Afghanistan                                         2.465221
# Albania                                            22.241690
# Algeria                                             5.064181
# Angola                                             12.863257
# Argentina                                          13.303817
#
# IndicatorCode  Depth of credit information index (0=low to 8=high)  \
# CountryName
# Afghanistan                                                  0.0
# Albania                                                      6.0
# Algeria                                                      0.0
# Angola                                                       0.0
# Argentina                                                    8.0
#
# IndicatorCode  Strength of legal rights index (0=weak to 12=strong)  \
# CountryName
# Afghanistan                                                  9.0
# Albania                                                      7.0
# Algeria                                                      2.0
# Angola                                                       1.0
# Argentina                                                    2.0
#
# IndicatorCode  Mobile cellular subscriptions (per 100 people)  \
# CountryName
# Afghanistan                                         74.882842
# Albania                                            105.469966
# Algeria                                             93.310750
# Angola                                              63.479208
# Argentina                                          158.735762
#
# IndicatorCode  Internet users (per 100 people)  GDP per capita (current US$)  \
# CountryName
# Afghanistan                               6.39                    633.569247
# Albania                                  60.10                   4564.390339
# Algeria                                  18.09                   5484.066806
# Angola                                   21.26                   5900.529570
# Argentina                                64.70                  12509.531118
#
# IndicatorCode  Proportion of seats held by women in national parliaments (%)  \
# CountryName
# Afghanistan                                            27.710843
# Albania                                                20.714286
# Algeria                                                31.601732
# Angola                                                 36.818182
# Argentina                                              36.186770
#
# IndicatorCode  Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# CountryName
# Afghanistan                                                 46.0
# Albania                                                      5.1
# Algeria                                                     14.5
# Angola                                                      66.4
# Argentina                                                   11.3
#
# IndicatorCode  Health expenditure per capita (current US$)  \
# CountryName
# Afghanistan                                      54.964148
# Albania                                         239.577092
# Algeria                                         313.520212
# Angola                                          267.224299
# Argentina                                      1074.066944
#
# IndicatorCode  Labor force, female (% of total labor force)  \
# CountryName
# Afghanistan                                       16.051439
# Albania                                           41.266475
# Algeria                                           17.376156
# Angola                                            46.204554
# Argentina                                         40.431360
#
# IndicatorCode  Unemployment, total (% of total labor force)  Net migration  \
# CountryName
# Afghanistan                                             9.1         473007
# Albania                                                16.1         -91750
# Algeria                                                 9.5        -143268
# Angola                                                  6.8         102322
# Argentina                                               8.2          30000
#
# IndicatorCode  Mortality rate, infant (per 1,000 live births)  \
# CountryName
# Afghanistan                                              66.3
# Albania                                                  12.5
# Algeria                                                  21.9
# Angola                                                   96.0
# Argentina                                                11.1
#
# IndicatorCode  Life expectancy at birth, total (years)  \
# CountryName
# Afghanistan                                  60.028268
# Albania                                      77.537244
# Algeria                                      74.568951
# Angola                                       51.866171
# Argentina                                    75.986098
#
# IndicatorCode  Survival to age 65, female (% of cohort)  \
# CountryName
# Afghanistan                                    60.48056
# Albania                                        90.56197
# Algeria                                        85.02157
# Angola                                         49.09112
# Argentina                                      87.23494
#
# IndicatorCode  Population, ages 0-14 (% of total)  \
# CountryName
# Afghanistan                             44.870996
# Albania                                 18.930427
# Algeria                                 28.205909
# Angola                                  47.850317
# Argentina                               25.346427
#
# IndicatorCode  Age dependency ratio, young (% of working-age population)  \
# CountryName
# Afghanistan                                            85.153384
# Albania                                                27.432462
# Algeria                                                42.742285
# Angola                                                 96.005760
# Argentina                                              39.700196
#
# IndicatorCode  Urban population (% of total)
# CountryName
# Afghanistan                           26.282
# Albania                               56.409
# Algeria                               70.129
# Angola                                43.274
# Argentina                             91.604

# %%
#Shape
df.shape
# Out:
# (159, 21)

# %% [markdown]
# 159 countries and 21 attributes.

# %%
#Look at columns
df.columns
# Out:
# Index([u'Access to electricity (% of population)',
#        u'Renewable electricity output (% of total electricity output)',
#        u'CO2 emissions (metric tons per capita)',
#        u'Commercial bank branches (per 100,000 adults)',
#        u'Depth of credit information index (0=low to 8=high)',
#        u'Strength of legal rights index (0=weak to 12=strong)',
#        u'Mobile cellular subscriptions (per 100 people)',
#        u'Internet users (per 100 people)', u'GDP per capita (current US$)',
#        u'Proportion of seats held by women in national parliaments (%)',
#        u'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
#        u'Health expenditure per capita (current US$)',
#        u'Labor force, female (% of total labor force)',
#        u'Unemployment, total (% of total labor force)', u'Net migration',
#        u'Mortality rate, infant (per 1,000 live births)',
#        u'Life expectancy at birth, total (years)',
#        u'Survival to age 65, female (% of cohort)',
#        u'Population, ages 0-14 (% of total)',
#        u'Age dependency ratio, young (% of working-age population)',
#        u'Urban population (% of total)'],
#       dtype='object', name=u'IndicatorCode')

# %%
#Rename cols to make things easier

new_cols = ["electric_accces", "renewables_percent", "co2_emissions", "commercial_bank",
           "credit_information_index_depth", "legal_rights", "cell_phone_usage",
           "internet_users","gdp_per_cap", "women_politicians", "communicable_disease_rate", "health_per_cap",
           "female_labor_rate", "unemploy_rate", "net_migration", "mortality_rate", "life_exp",
           "female_survival_65", "child_popul", "age_depend_ratio", "urban_pop"]
df.columns = new_cols

df.head()
# Out:
#              electric_accces  renewables_percent  co2_emissions  \
# CountryName
# Afghanistan             43.0            0.000000       0.425262
# Albania                100.0          100.000000       1.607038
# Algeria                100.0            1.083680       3.316038
# Angola                  37.0           70.906823       1.354008
# Argentina               99.8           23.769069       4.562049
#
#              commercial_bank  credit_information_index_depth  legal_rights  \
# CountryName
# Afghanistan         2.465221                             0.0           9.0
# Albania            22.241690                             6.0           7.0
# Algeria             5.064181                             0.0           2.0
# Angola             12.863257                             0.0           1.0
# Argentina          13.303817                             8.0           2.0
#
#              cell_phone_usage  internet_users   gdp_per_cap  \
# CountryName
# Afghanistan         74.882842            6.39    633.569247
# Albania            105.469966           60.10   4564.390339
# Algeria             93.310750           18.09   5484.066806
# Angola              63.479208           21.26   5900.529570
# Argentina          158.735762           64.70  12509.531118
#
#              women_politicians  communicable_disease_rate  health_per_cap  \
# CountryName
# Afghanistan          27.710843                       46.0       54.964148
# Albania              20.714286                        5.1      239.577092
# Algeria              31.601732                       14.5      313.520212
# Angola               36.818182                       66.4      267.224299
# Argentina            36.186770                       11.3     1074.066944
#
#              female_labor_rate  unemploy_rate  net_migration  mortality_rate  \
# CountryName
# Afghanistan          16.051439            9.1         473007            66.3
# Albania              41.266475           16.1         -91750            12.5
# Algeria              17.376156            9.5        -143268            21.9
# Angola               46.204554            6.8         102322            96.0
# Argentina            40.431360            8.2          30000            11.1
#
#               life_exp  female_survival_65  child_popul  age_depend_ratio  \
# CountryName
# Afghanistan  60.028268            60.48056    44.870996         85.153384
# Albania      77.537244            90.56197    18.930427         27.432462
# Algeria      74.568951            85.02157    28.205909         42.742285
# Angola       51.866171            49.09112    47.850317         96.005760
# Argentina    75.986098            87.23494    25.346427         39.700196
#
#              urban_pop
# CountryName
# Afghanistan     26.282
# Albania         56.409
# Algeria         70.129
# Angola          43.274
# Argentina       91.604

# %% [markdown]
# Let's pick 5 - 7 of the 21 attributes to work with. Attributes need to be fairly different from one another.

# %%
df.columns
# Out:
# Index([u'electric_accces', u'renewables_percent', u'co2_emissions',
#        u'commercial_bank', u'credit_information_index_depth', u'legal_rights',
#        u'cell_phone_usage', u'internet_users', u'gdp_per_cap',
#        u'women_politicians', u'communicable_disease_rate', u'health_per_cap',
#        u'female_labor_rate', u'unemploy_rate', u'net_migration',
#        u'mortality_rate', u'life_exp', u'female_survival_65', u'child_popul',
#        u'age_depend_ratio', u'urban_pop'],
#       dtype='object')

# %%
#Creat subset list of columns
subset = ['gdp_per_cap', 'life_exp', "urban_pop", "net_migration", 'unemploy_rate',
         'legal_rights', 'internet_users']


df2 = df[subset]

# %% [markdown]
# Let's cluster the countries using 2, 3, and 5 clusters

# %% [markdown]
# 2 Clusters:

# %%
# X

# %%
#Make a copy of df2 and assign it to X
X = df2.copy()

#Intialize kmeans with 2 clusters and random_state = 10
km2 = KMeans(n_clusters=2, random_state=10)

#Fit model on X
km2.fit(X)

#Generate labels

##Method 1
labs2 = km2.labels_

##Method 2
labs2 = km2.predict(X)



#Value_counts
pd.value_counts(labs2)
# Out:
# 1    149
# 0     10
# dtype: int64

# %%
#Cluster centriods
km2.cluster_centers_
# Out:
# array([[  3.37723657e+04,   7.81836829e+01,   8.04414000e+01,
#           1.57857420e+06,   6.38999996e+00,   5.80000000e+00,
#           7.67020000e+01],
#        [  1.33362100e+04,   7.01274182e+01,   5.71652685e+01,
#          -8.02801544e+04,   8.86711414e+00,   5.04026846e+00,
#           4.21585905e+01]])

# %%
#Add labels to the dataframe and view centriods using pandas

df2["labs2"] = labs2

df2.groupby("labs2").mean()
# Out:
# /Users/sjohnston/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         gdp_per_cap   life_exp  urban_pop  net_migration  unemploy_rate  \
# labs2
# 0      33772.365719  78.183683  80.441400   1.578574e+06       6.390000
# 1      13336.209983  70.127418  57.165268  -8.028015e+04       8.867114
#
#        legal_rights  internet_users
# labs2
# 0          5.800000        76.70200
# 1          5.040268        42.15859

# %% [markdown]
# What separates the two clusters? How would you describe cluster 0 and cluster 1?

# %%
df2["labs2"].value_counts()
# Out:
# 1    149
# 0     10
# Name: labs2, dtype: int64

# %% [markdown]
# ### Evaluation clusters silhouette score

# %% [markdown]
# The [Silhouette Coefficient](http://scikit-learn.org/stable/modules/clustering.html#silhouette-coefficient) is a common metric for evaluating clustering "performance" in situations when the "true" cluster assignments are not known.
#
# A Silhouette Coefficient is calculated for **each observation**:
#
# $$SC = \frac{b-a} {max(a, b)}$$
#
# - a = mean distance to all other points in **its cluster**
# - b = mean distance to all other points in **the next nearest cluster**
#
# It ranges from -1 (worst) to 1 (best). A **global score** is calculated by taking the mean score for all observations. Ideally, you want a score greater than at least 0.2.

# %% [markdown]
# ![w](http://scikit-learn.org/stable/_images/sphx_glr_plot_kmeans_silhouette_analysis_001.png)
#
# ![a](http://scikit-learn.org/stable/_images/sphx_glr_plot_kmeans_silhouette_analysis_002.png)
#
# ![e](http://scikit-learn.org/stable/_images/sphx_glr_plot_kmeans_silhouette_analysis_003.png)
#
# ![t](http://scikit-learn.org/stable/_images/sphx_glr_plot_kmeans_silhouette_analysis_004.png)
#
# ![y](http://scikit-learn.org/stable/_images/sphx_glr_plot_kmeans_silhouette_analysis_005.png)
# Source: Sci-kit learn

# %% [markdown]
# Derive silhouette score of country data and labels

# %%
#Pass in df2 without labs2 column and the labs2 variable into silhouette_score function
silhouette_score(X, labs2)
# Out:
# 0.78822489298571252

# %% [markdown]
# 3 Clusters

# %%
#Intialize kmeans with 3 clusters and random_state = 10
km3 = KMeans(n_clusters=3, random_state=10)

#Fit model
km3.fit(X)

#Generate labels

##Method 1
labs3 = km3.labels_

##Method 2
#lab3 = km3.predict(X)

#Add labs3 to df2
df2["labs3"] = labs3


#Value_counts
pd.value_counts(labs3)
# Out:
# /Users/sjohnston/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# 0    154
# 1      4
# 2      1
# dtype: int64

# %% [markdown]
# Silhouette scoring

# %%
silhouette_score(X, labs3)
# Out:
# 0.81645969125410611

# %% [markdown]
# Analyze clusters by looking at centriods

# %%
df2.groupby("labs3").mean()
# Out:
#         gdp_per_cap   life_exp  urban_pop  net_migration  unemploy_rate  \
# labs3
# 0      14666.327929  70.595833  58.974006   4.235538e+04       8.838312
# 1       2893.737083  70.055591  39.648750  -1.926654e+06       4.450000
# 2      54629.495168  78.841463  81.447000   5.007887e+06       6.200000
#
#        legal_rights  internet_users     labs2
# labs3
# 0          5.058442       44.614221  0.941558
# 1          4.750000       22.675000  1.000000
# 2         11.000000       87.360000  0.000000

# %%
df2["labs3"].value_counts()
# Out:
# 0    154
# 1      4
# 2      1
# Name: labs3, dtype: int64

# %% [markdown]
# What are the three types of countries?

# %%
#df2.loc[df['labs3'].isin(2)]
df2.loc[df2['labs3'] == 2]
# Out:
#                 gdp_per_cap   life_exp  urban_pop  net_migration  \
# CountryName
# United States  54629.495168  78.841463     81.447        5007887
#
#                unemploy_rate  legal_rights  internet_users  labs2  labs3
# CountryName
# United States            6.2          11.0           87.36      0      2

# %%
df2.loc[df2['labs3'] == 1]
# Out:
#              gdp_per_cap   life_exp  urban_pop  net_migration  unemploy_rate  \
# CountryName
# Bangladesh   1086.807079  71.245244     33.516       -2226481            4.3
# China        7590.016441  75.353024     54.410       -1800000            4.7
# India        1581.510703  67.660415     32.366       -2598218            3.6
# Pakistan     1316.614110  65.963683     38.303       -1081918            5.2
#
#              legal_rights  internet_users  labs2  labs3
# CountryName
# Bangladesh            6.0             9.6      1      1
# China                 4.0            49.3      1      1
# India                 6.0            18.0      1      1
# Pakistan              3.0            13.8      1      1

# %%
df2.loc[df2['labs3'] == 0]
# Out:
#                            gdp_per_cap   life_exp  urban_pop  net_migration  \
# CountryName
# Afghanistan                 633.569247  60.028268     26.282         473007
# Albania                    4564.390339  77.537244     56.409         -91750
# Algeria                    5484.066806  74.568951     70.129        -143268
# Angola                     5900.529570  51.866171     43.274         102322
# Argentina                 12509.531118  75.986098     91.604          30000
# Bhutan                        0
# Bolivia                       0
# Bosnia and Herzegovina        0
# Botswana                      0
# Brazil                        0
# Bulgaria                      0
# Burkina Faso                  0
# Burundi                       0
# Cabo Verde                    0
# Cambodia                      0
# Cameroon                      0
# Canada                        0
# Central African Republic      0
# Chad                          0
# ...                         ...
# Sierra Leone                  0
# Singapore                     0
# Slovak Republic               0
# Slovenia                      0
# South Africa                  0
# Spain                         0
# Sri Lanka                     0
# Sudan                         0
# Suriname                      0
# Swaziland                     0
# Sweden                        0
# Switzerland                   0
# Tajikistan                    0
# Tanzania                      0
# Thailand                      0
# Togo                          0
# Trinidad and Tobago           0
# Tunisia                       0
# Turkey                        0
# Turkmenistan                  0
# Uganda                        0
# Ukraine                       0
# United Kingdom                0
# Uruguay                       0
# Uzbekistan                    0
# Venezuela, RB                 0
# Vietnam                       0
# Yemen, Rep.                   0
# Zambia                        0
# Zimbabwe                      0
#
# [154 rows x 9 columns]

# %% [markdown]
# Let's compare the two sets of labels

# %%
#Pass in the labs2 and labs3 columns of df2 into pandas crosstab function

pd.crosstab(df2.labs2, df2.labs3)
# Out:
# labs3    0  1  2
# labs2
# 0        9  0  1
# 1      145  4  0

# %% [markdown]
# What do you notice about this table?

# %% [markdown]
# Exercise: Analyze the data using five clusters

# %%
#Intialize kmeans with 5 clusters
km5 = KMeans(n_clusters=5, random_state=10)

#Fit model
km5.fit(X)

#Generate labels

##Method 1
labs5 = km5.labels_

##Method 2
#lab5 = km5.predict(X)

#Add labs3 to df2
df2["labs5"] = labs5


#Value_counts
pd.value_counts(labs5)
# Out:
# /Users/sjohnston/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# 4    128
# 0     17
# 1     10
# 3      3
# 2      1
# dtype: int64

# %%
#Silhoeute score
silhouette_score(X, labs5)
# Out:
# 0.63066908554789358

# %%
#Centriods
df2.groupby("labs5").mean()
# Out:
#         gdp_per_cap   life_exp  urban_pop  net_migration  unemploy_rate  \
# labs5
# 0       5741.928579  70.246098  53.747353  -4.814364e+05       9.341177
# 1      28957.698350  75.973195  78.726500   1.137786e+06       8.280000
# 2      54629.495168  78.841463  81.447000   5.007887e+06       6.200000
# 3       3419.444741  71.419561  40.097333  -2.208233e+06       4.200000
# 4      14630.791764  70.185987  57.963516   1.755761e+04       8.786719
#
#        legal_rights  internet_users  labs2     labs3
# labs5
# 0          5.294118       34.915294    1.0  0.058824
# 1          5.200000       72.866000    0.1  0.000000
# 2         11.000000       87.360000    0.0  2.000000
# 3          5.333333       25.633333    1.0  1.000000
# 4          5.000000       43.454453    1.0  0.000000

# %%
pd.crosstab(df2.labs3, df2.labs5)
# Out:
# labs5   0   1  2  3    4
# labs3
# 0      16  10  0  0  128
# 1       1   0  0  3    0
# 2       0   0  1  0    0

# %% [markdown]
# What are the five different types of countries?

# %% [markdown]
# Plotting time. Let's plot a range of cluster values versus silhouette scores. Make a validation curve similar to how we did with KNN and neighbors or Decision Trees and max_depth.

# %%
#Intialize range of cluster values from 2 to 16
cluster_range = range(2, 17)

#Intialize list to store silhouette scores

s_scores = []

#Iterate over cluster range, fit models and add score to s_scores

for cluster in cluster_range:
    model = KMeans(n_clusters=cluster)
    model.fit(X)
    labels = model.labels_
    score = silhouette_score(X, labels)
    s_scores.append(score)
    
#Plot clusters versus scores

plt.figure(figsize=(10, 7))
plt.plot(cluster_range, s_scores, linewidth = 6, alpha = .8, c = "r")
plt.xlabel("K Values")
plt.ylabel("Silhoeuette Scores");

# %% [markdown]
# Whats the best cluster value?

# %% [markdown]
# Elbow method cluster evaluation

# %%
#Call interia score on km5 - this would be zero if k = 159 (i.e. the number of country rows in the data) since there would be a centroid on every data point...
km5.inertia_
# Out:
# 5590433389062.8447

# %% [markdown]
# ["Inertia, or the within-cluster sum of squares criterion (SSE), can be recognized as a measure of how internally coherent clusters are."](http://scikit-learn.org/stable/modules/clustering.html)

# %% [markdown]
# We're going to plot a range of cluster values versus the inertia score in order to determine the best cluster value using the "elbow method."

# %%
#Intialize range of cluster values from 2 to 16
cluster_range = range(2, 17)

#Intialize list to store inertia scores
i_scores = []

#Iterate over cluster range, fit models and add score to s_scores
for cluster in cluster_range:
    model = KMeans(n_clusters=cluster)
    model.fit(X)
    score = model.inertia_
    i_scores.append(score)

#Plot clusters versus scores
plt.plot(cluster_range, i_scores)

plt.show()

# %% [markdown]
# Where is the "elbow" in this chart? The elbow is where the best K value lies.
#
# Imagine the line as an arm.

# %%
#Intialize range of cluster values from 2 to 16
cluster_range_all = range(2, 159)

#Intialize list to store inertia scores
i_scores_all = []

#Iterate over cluster range, fit models and add score to s_scores
for cluster in cluster_range_all:
    model = KMeans(n_clusters=cluster)
    model.fit(X)
    score = model.inertia_
    i_scores_all.append(score)
    
plt.plot(cluster_range_all, i_scores_all)
plt.show()

# %% [markdown]
# Increasing K is always going to decrease the SSE, but what's the point of using a KMeans algorithm with 1000 K-value algorithm on a 1000 row dataset.
#
# We want to choose a K that's at the beginning of the diminishing margin of returns.

# %% [markdown]
# ### Scaling features and KMeans

# %% [markdown]
# We're going to demonstrate the need for scaling by clustering the data with all of the attributes

# %%
#Reassign X
X = df.copy()

# %% [markdown]
# Cluster with k = 3

# %%
#Intialize kmeans with 3 clusters and random_state = 10
km3 = KMeans(n_clusters=3, random_state=10)

#Fit model
km3.fit(X)

#Generate labels

labs3 = km3.labels_

#Value_counts
pd.value_counts(labs3)
# Out:
# 0    154
# 1      4
# 2      1
# dtype: int64

# %%
#Silhouette score
silhouette_score(X, labs3)
# Out:
# 0.81645134382385731

# %% [markdown]
# You can't really say that there are clusters here. Two-thirds of the clusters only account for 3 percent of the data. This is evidence of outliers skewing the dataset. So even though, we're producing a high silhouette score, this isn't much of a cluster analysis

# %% [markdown]
# Let's go ahead and scale the data and refit a clustering algorithm

# %%
#Intialize scaler
ss = StandardScaler()

#Fit and transform scaler on data
#ss.fit(X)
#Xs = ss.transform(X)
Xs = ss.fit_transform(X)

#Intialize kmeans with 3 clusters and random_state = 10
km3_s = KMeans(n_clusters=3, random_state=10)

#Fit model
km3_s.fit(Xs)

#Generate labels
labs3_s = km3_s.labels_

#Value_counts
pd.value_counts(labs3_s)
# Out:
# 0    85
# 1    49
# 2    25
# dtype: int64

# %%
#Score
silhouette_score(Xs, labs3_s)
# Out:
# 0.25321740998862929

# %% [markdown]
# Let's go ahead and look at some of the countries in each cluster.
#
# We're going randomly pick 10 countries from each cluster (0, 1, 2)

# %%
#Create dataframe with countries as indices and use labs3_s as the values

country_labels = pd.DataFrame(index=df.index, data=labs3_s, columns=["clusters3"])
country_labels.head()
# Out:
#              clusters3
# CountryName
# Afghanistan          1
# Albania              0
# Algeria              0
# Angola               1
# Argentina            0

# %%
#Cluster 0
country_labels[country_labels.clusters3 == 0].sample(n=10).index
# Out:
# Index([u'Vietnam', u'Lebanon', u'Paraguay', u'Sri Lanka', u'Brazil',
#        u'Morocco', u'Serbia', u'Indonesia', u'Turkey', u'Cuba'],
#       dtype='object', name=u'CountryName')

# %%
#Cluster 1
country_labels[country_labels.clusters3 == 1].sample(n=10).index
# Out:
# Index([u'Uganda', u'Chad', u'Bangladesh', u'Eritrea', u'Gambia, The',
#        u'Lesotho', u'Liberia', u'Equatorial Guinea', u'Ghana', u'Burundi'],
#       dtype='object', name=u'CountryName')

# %%
#Cluster 2
country_labels[country_labels.clusters3 == 0].sample(n=10).index
# Out:
# Index([u'Jamaica', u'Fiji', u'Spain', u'Morocco', u'Ecuador', u'South Africa',
#        u'Romania', u'Cabo Verde', u'Venezuela, RB', u'Mongolia'],
#       dtype='object', name=u'CountryName')

# %% [markdown]
# Let's make validation curves using both silhoeutte and inertia scores

# %% [markdown]
# Sihouette Score Plot:

# %%
#Intialize range of cluster values from 2 to 16
cluster_range = range(2, 17)

#Intialize list to store silhouette scores

s_scores = []

#Iterate over cluster range, fit models and add score to s_scores

for cluster in cluster_range:
    model = KMeans(n_clusters=cluster)
    model.fit(Xs)
    labels = model.labels_
    score = silhouette_score(Xs, labels)
    s_scores.append(score)
    
#Plot clusters versus scores

plt.figure(figsize=(10, 7))
plt.plot(cluster_range, s_scores, linewidth = 6, alpha = .8, c = "r")
plt.xlabel("Cluster Values")
plt.ylabel("Silhoeuette Scores");

# %% [markdown]
# Inertia Scores Plot:

# %%
#Intialize range of cluster values from 2 to 16
cluster_range = range(2, 17)

#Intialize list to store inertia scores

i_scores = []

#Iterate over cluster range, fit models and add score to s_scores

for cluster in cluster_range:
    model = KMeans(n_clusters=cluster)
    model.fit(Xs)
    
    score = model.inertia_
    i_scores.append(score)
    
#Plot clusters versus scores

plt.figure(figsize=(10, 7))
plt.plot(cluster_range, i_scores, linewidth = 6, alpha = .8, c = "g")
plt.xlabel("Cluster Values")
plt.ylabel("Inertia Scores");

# %% [markdown]
# * BUT - there is no clear elbow ascernable in the graph above...

# %% [markdown]
# What's the ideal number of clusters? Which plot should we use to determine that ?

# %%
countrya=(50000, 80)
countryb=(10000, 60)

countryx=(14000, 76)

ax=countrya[0] - countryx[0]
ay=countrya[1] - countryx[1]


ax_dist = np.sqrt((ax**2) + (ay**2))
print ax_dist

bx=countryb[0] - countryx[0]
by=countryb[1] - countryx[1]

bx_dist = np.sqrt((bx**2) + (by**2))
print bx_dist
# Out:
# 36000.0002222
# 4000.03199987

# %%
def get_euclidian_distance(pointa, pointb):
    ab_x=pointa[0] - pointb[0]
    ab_y=pointa[1] - pointb[1]

    return np.sqrt((ab_x**2) + (ab_y**2))

countrya=(50000, 80)
countryb=(10000, 60)
countryx=(14000, 76)

print get_euclidian_distance(countrya, countryx)
print get_euclidian_distance(countryb, countryx)
# Out:
# 36000.0002222
# 4000.03199987

# %%
pd.DataFrame(Xs, index=df.index, columns=X.columns)
# Out:
#                           electric_accces  renewables_percent  co2_emissions  \
# CountryName
# Afghanistan                     -1.150520           -0.852899      -0.692113
# Albania                          0.698238            2.341307      -0.505066
# Algeria                          0.698238           -0.818285      -0.234572
# Angola                          -1.345126            1.412011      -0.545115
# Argentina                        0.691751           -0.093666      -0.037358
# Armenia                          0.698238            0.071655      -0.494838
# Australia                        0.698238           -0.545214       1.855176
# Austria                          0.698238            1.528219       0.470382
# Azerbaijan                       0.698238           -0.599870      -0.182128
# Bahamas, The                     0.698238           -0.852899       0.063590
# Bahrain                          0.623568           -0.852899       2.081214
# Bangladesh                      -0.612110           -0.802289      -0.700540
# Barbados                         0.402288           -0.852899       0.123788
# Belarus                          0.698238           -0.835165       0.298261
# Belgium                          0.698238           -0.444410       0.641228
# Belize                           0.698238           -0.852899      -0.494957
# Benin                           -1.299718           -0.833303      -0.678707
# Bhutan                          -0.094375           -0.852899      -0.638150
# Bolivia                          0.390111            0.225317      -0.506259
# Bosnia and Herzegovina           0.698238            0.103185       0.221361
# Botswana                        -0.818392           -0.852899      -0.391692
# Brazil                           0.682020            1.781408      -0.412576
# Bulgaria                         0.698238           -0.487595       0.303305
# Burkina Faso                    -2.120307           -0.852899      -0.740432
# Burundi                         -2.334374           -0.852899      -0.756043
# Cabo Verde                      -0.256547           -0.852899      -0.623453
# Cambodia                        -1.536489            0.349940      -0.710661
# Cameroon                        -0.803473            1.480158      -0.716989
# Canada                           0.698238            1.167387       1.477941
# Central African Republic        -2.194906           -0.852899      -0.749430
# ...                                   ...                 ...            ...
# Singapore                        0.698238           -0.809462      -0.075645
# Slovak Republic                  0.698238           -0.235663       0.248409
# Slovenia                         0.698238            0.035419       0.428324
# South Africa                     0.224696           -0.822366       0.705775
# Spain                            0.698238            0.092098       0.157118
# Sri Lanka                        0.330515            0.081126      -0.643893
# Sudan                           -1.489052            1.387716      -0.704097
# Suriname                         0.698238           -0.852899      -0.181727
# Swaziland                       -1.182954           -0.852899      -0.622515
# Sweden                           0.698238            1.033846       0.114013
# Switzerland                      0.698238            1.046960      -0.027358
# Tajikistan                       0.698238            2.327381      -0.702609
# Tanzania                        -2.048951            0.078078      -0.734899
# Thailand                         0.698238           -0.588788      -0.041720
# Togo                            -1.524729            1.852104      -0.708862
# Trinidad and Tobago              0.692652           -0.852899       5.118966
# Tunisia                          0.698238           -0.797665      -0.379170
# Turkey                           0.698238            0.016899      -0.065681
# Turkmenistan                     0.698238           -0.852899       1.168963
# Uganda                          -1.956106           -0.852899      -0.741871
# Ukraine                          0.698238           -0.672000       0.231760
# United Kingdom                   0.698238           -0.487692       0.362081
# United States                    0.698238           -0.469433       1.934474
# Uruguay                          0.682020            1.118769      -0.395988
# Cameroon                                   1.545838       -0.562932
# Canada                                    -0.849445        2.361882
# Central African Republic                   2.089232       -0.590945
# ...                                             ...             ...
# Singapore                                 -0.258232        0.700130
# Slovak Republic                           -0.858140        0.154924
# Slovenia                                  -0.932041        0.481269
# South Africa                               1.024179       -0.290532
# Spain                                     -0.879875        0.738222
# Sri Lanka                                 -0.601657       -0.544649
# Sudan                                      1.211107       -0.538201
# Suriname                                  -0.358217       -0.367523
# Swaziland                                  1.658864       -0.465137
# Sweden                                    -0.858140        2.342400
# Switzerland                               -0.923347        4.203735
# Tajikistan                                 0.215608       -0.561481
# Tanzania                                   1.432812       -0.572171
# Thailand                                  -0.284315       -0.460876
# Togo                                       1.606698       -0.569518
# Trinidad and Tobago                       -0.710336       -0.082537
# Tunisia                                   -0.614699       -0.437989
# Turkey                                    -0.771196       -0.283154
# Turkmenistan                              -0.506020       -0.516158
# Uganda                                     1.524102       -0.567101
# Ukraine                                   -0.862487       -0.435856
# United Kingdom                            -0.771196        1.264556
# United States                             -0.836404        4.136115
# Uruguay                                   -0.749461        0.143055
# Uzbekistan                                -0.488631       -0.535611
# Venezuela, RB                             -0.601657       -0.328740
# Vietnam                                   -0.362564       -0.540159
# Yemen, Rep.                                1.093734       -0.559154
# Zambia                                     1.815362       -0.549662
# Zimbabwe                                   1.589309       -0.567679
#
#                           female_labor_rate  unemploy_rate  net_migration  \
# CountryName
# Afghanistan                       -2.880351       0.063719       0.718567
# Albania                           -0.027399       1.211283      -0.185341
# Algeria                           -2.730466       0.129294      -0.267797
# Angola                             0.531320      -0.313337       0.125276
# Argentina                         -0.121888      -0.083825       0.009523
# Armenia                            0.528298       1.375220      -0.054300
# Australia                          0.439024      -0.444487       1.599016
# Austria                            0.508739      -0.608425       0.196927
# Azerbaijan                         0.805771      -0.575638      -0.064302
# Bahamas, The                       0.768496       1.096526      -0.023013
# Bahrain                           -2.482753      -0.788756       0.009387
# Bangladesh                        -0.123961      -0.723181      -3.602033
# Barbados                           0.836261       0.539138      -0.035004
# Belarus                            0.816690      -0.460881       0.154426
# Belgium                            0.483814      -0.034643       0.393646
# Belize                            -0.403041       0.457169      -0.026339
# Benin                              0.622242      -1.264176      -0.054498
# Bhutan                            -0.004272      -0.969088      -0.022488
# Bolivia                            0.353342      -0.985482      -0.137396
# Bosnia and Herzegovina            -0.392095       3.145746      -0.042504
# Botswana                           0.628606       1.555552      -0.006483
# Brazil                             0.256347      -0.313337      -0.013006
# Bulgaria                           0.577196       0.473563      -0.118519
# Burkina Faso                       0.657891      -0.919907      -0.238559
# Burundi                            1.129175      -0.296944       0.025528
# Cabo Verde                        -0.257194       0.080113      -0.056182
# Cambodia                           0.940508      -1.362538      -0.278570
# Cameroon                           0.474456      -0.723181      -0.134525
# Canada                             0.635084      -0.296944       1.843506
# Central African Republic           0.632134      -0.214975      -0.022488
# ...                                     ...            ...            ...
# Singapore                          0.305179      -0.936300       0.598414
# Slovak Republic                    0.367101       0.752257      -0.036574
# Slovenia                           0.516042       0.129294      -0.031572
# South Africa                       0.264068       2.686721       0.921822
# Spain                              0.468019       2.621146      -0.987715
# Swaziland                    0.892325          0.762461  -1.669736
# Sweden                      -1.005043         -0.832796   1.209800
# Switzerland                 -1.217698         -1.051191   0.680833
# Tajikistan                   0.645894          0.436574  -1.429126
# Tanzania                     1.599246          1.794862  -1.240781
# Thailand                    -0.921358         -0.918381  -0.423100
# Togo                         1.339219          1.348161  -0.857380
# Trinidad and Tobago         -0.661338         -0.715578  -2.240944
# Tunisia                     -0.428857         -0.542927   0.358692
# Turkey                      -0.184199         -0.315634   0.638188
# Turkmenistan                 0.042617         -0.179048  -0.400100
# Uganda                       1.884435          2.250561  -1.918042
# Ukraine                     -1.232963         -1.098174   0.485642
# United Kingdom              -0.946049         -0.817094   1.061236
# United States               -0.820806         -0.760194   1.021053
# Uruguay                     -0.584540         -0.539346   1.634324
# Uzbekistan                   0.055181         -0.152635  -1.000171
# Venezuela, RB                0.043800         -0.122499   1.356394
# Vietnam                     -0.446492         -0.576548  -1.149048
# Yemen, Rep.                  1.176238          1.107348  -1.100899
# Zambia                       1.678002          1.910102  -0.812498
# Zimbabwe                     1.261277          1.246152  -1.169184
#
# [159 rows x 21 columns]

# %% [markdown]
# **The hardest part of clustering is that it's hard to find the right answers!!**

# %% [markdown]
# # Resources:
#
# **Kmeans:**
#
# - https://kapilddatascience.wordpress.com/2015/09/06/introduction-to-k-means-clustering-part-1/
# - http://fromdatawithlove.thegovans.us/2013/05/clustering-using-scikit-learn.html
# - Great code walk through of clustering project:https://github.com/net70/KMeans-Clustering---Scikit-Learn/blob/master/KMeans%20Clustering%20-%20Scikit-Learn.ipynb
# - My favorite tutorial: https://www.datascience.com/blog/k-means-clustering
# - Really like this too: https://github.com/YuChunLOL/kmeans-dbscan-tutorial/blob/master/tutorial_and_labs/clustering-tutorial.ipynb
#
#
# ## Other types of clustering
#
# **Hierarchical/Agglomerative**
#
# - https://onlinecourses.science.psu.edu/stat505/node/143
# - https://www.youtube.com/watch?v=XJ3194AmH40
# - http://uc-r.github.io/hc_clustering (In R, but still a good resource)
# - http://people.revoledu.com/kardi/tutorial/Clustering/index.html
# - https://www.coursera.org/learn/cluster-analysis/lecture/LYX9a/4-2-agglomerative-clustering-algorithms
# - https://blog.biolab.si/2015/12/02/hierarchical-clustering-a-simple-explanation/
#
# **DBScan**
#
# - https://blog.dominodatalab.com/topology-and-density-based-clustering/
# - https://www.naftaliharris.com/blog/visualizing-dbscan-clustering/
# - https://www.slideshare.net/ssakpi/density-based-clustering

# %% [markdown]
# # In Class Lab
#
# For the rest of class, I want you to work on clustering a dataset.
#
# - I recommend picking any of the following datasets:
#     - amazon_cities_data.csv, fifa_data.csv, mushrooms.csv, spotify_data.csv, Pokemon.csv, world-happiness-report folder, acs2015_county_data.csv, nba_player_stats.csv, diamonds.csv.
#     - You can also use any of other supervised learning datasets we've used, just make sure to remove the target variable.
#
# - Determine the right number of clusters using both silhouette score and elbow methods. Cluster using both scaled and unscaled versions of the data.
#
# - Use EDA to learn about your clusters. Visualize the differences between thems. Don't just use the avearage attributes of each cluster's attributes.
#
# - At the end of the class, each one of use will take 2-3 minutes to explain their clustering. Tell us what dataset you chose, how many clusters there are, and briefly describe the characteristics of each cluster.
